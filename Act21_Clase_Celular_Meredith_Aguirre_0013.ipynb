# %% [markdown]
# <a href="https://colab.research.google.com/github/JazminAguirre128/ACT21-clase-celular-Python-fecha-abril-2026/blob/main/Act21_Clase_Celular_Meredith_Aguirre_0013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Meredith Aguirre NL = 2 Fecha 22/Abril/2026
# ## Clase Celular
#
# ![celularcodigo](https://raw.githubusercontent.com/JazminAguirre128/ACT21-clase-celular-Python-fecha-abril-2026/refs/heads/main/infoClaseCelular(2).png)

# %%
class Celular:
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    def encender(self):
        self.encendido = True
        print(f"El {self.modelo} se ha encendido.")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo}, Precio: ${self.precio}")

# Instanciación
cel1 = Celular("Samsung", "Galaxy S23", 800)
cel2 = Celular("Apple", "iPhone 15", 1000)
# llamadas a las  funciones para cada objeto  celular 1 y celular 2
print("Celular 1:")
cel1.mostrar_info()
cel1.encender()

print("\nCelular 2:")
cel2.mostrar_info()
cel2.encender()

print("Programa terminado")
print("Creador del softwre por Meredith Aguirre NL = 2")
# Out:
# Celular 1:
# Celular: Samsung Galaxy S23, Precio: $800
# El Galaxy S23 se ha encendido.
#
# Celular 2:
# Celular: Apple iPhone 15, Precio: $1000
# El iPhone 15 se ha encendido.
# Programa terminado
# Creador del softwre por Meredith Aguirre NL = 2

# %% [markdown]
# ![funcionamiento](https://raw.githubusercontent.com/JazminAguirre128/ACT21-clase-celular-Python-fecha-abril-2026/refs/heads/main/LogicaFuncionamiento.PNG)
